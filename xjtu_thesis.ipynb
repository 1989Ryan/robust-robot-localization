# %% [markdown]
# # Demo for SeqSLAM
#
# ## Setup
#
# First, find the source code from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp "/content/drive/My Drive/pySeqSLAM/pyseqslam/__init__.py" "/content"
# !cp "/content/drive/My Drive/pySeqSLAM/pyseqslam/seqslam.py" "/content"
# !cp "/content/drive/My Drive/pySeqSLAM/pyseqslam/parameters.py" "/content"
# !cp "/content/drive/My Drive/pySeqSLAM/pyseqslam/utils.py" "/content"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import torch
import torchvision
import torch.utils.model_zoo as model_zoo
import torch.backends.cudnn as cudnn
import torch.nn as nn
model = torchvision.models.alexnet(num_classes=365)
checkpoint = model_zoo.load_url("http://places2.csail.mit.edu/models_places365/alexnet_places365.pth.tar")
model.features = nn.DataParallel(model.features)
cudnn.benchmark = True
model = model.cuda()
model.load_state_dict(checkpoint, strict=False)
# Out:
# Downloading: "http://places2.csail.mit.edu/models_places365/alexnet_places365.pth.tar" to /root/.cache/torch/checkpoints/alexnet_places365.pth.tar
# ...
# _IncompatibleKeys(missing_keys=['features.module.0.weight', 'features.module.0.bias', 'features.module.3.weight', 'features.module.3.bias', 'features.module.6.weight', 'features.module.6.bias', 'features.module.8.weight', 'features.module.8.bias', 'features.module.10.weight', 'features.module.10.bias', 'classifier.1.weight', 'classifier.1.bias', 'classifier.4.weight', 'classifier.4.bias', 'classifier.6.weight', 'classifier.6.bias'], unexpected_keys=['state_dict', 'epoch', 'arch', 'best_prec1'])

# %%
from seqslam import SeqSLAM

# %% [markdown]
# Download the dataset example

# %%
# !wget https://robotcar-dataset.robots.ox.ac.uk/downloads/sample.tar
# !tar -xvf sample.tar
# Out:
# --2020-02-08 10:39:32--  https://robotcar-dataset.robots.ox.ac.uk/downloads/sample.tar
# Resolving robotcar-dataset.robots.ox.ac.uk (robotcar-dataset.robots.ox.ac.uk)... 129.67.95.104
# Connecting to robotcar-dataset.robots.ox.ac.uk (robotcar-dataset.robots.ox.ac.uk)|129.67.95.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1038269952 (990M) [application/x-tar]
# Saving to: ‘sample.tar’
#
# sample.tar          100%[===================>] 990.17M  21.2MB/s    in 48s
#
# 2020-02-08 10:40:21 (20.5 MB/s) - ‘sample.tar’ saved [1038269952/1038269952]
#
# gps/
# gps/._gps.csv
# gps/gps.csv
# gps/._ins.csv
# gps/ins.csv
# ldmrs/
# ldmrs/._1418381798113072.bin
# ldmrs/1418381798113072.bin
# ldmrs/._1418381798194848.bin
# ldmrs/1418381798194848.bin
# ldmrs/._1418381798272925.bin
# ldmrs/1418381798272925.bin
# ldmrs/._1418381798352274.bin
# ldmrs/1418381798352274.bin
# ldmrs/._1418381798431992.bin
# ldmrs/1418381798431992.bin
# ldmrs/._1418381798512417.bin
# ...
